# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sc
import os

# %%
path=r"C:\Users\akash\OneDrive\Desktop\data science\data files\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dtype=visa_df.dtypes
dtype
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
data=dict(dtype)
data
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cat=[visa_df.select_dtypes(include='object').columns]
cat
# Out:
# [Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object')]

# %%
nume=[visa_df.select_dtypes(exclude='object').columns]
nume
# Out:
# [Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')]

# %%
cat1=[i for i,j in data.items() if j=='object' ]
cat1
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
nume1=[i for i,j in data.items() if j!='object' ]
nume1
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **how to select a specific column**

# %%
visa_df['continent'] #series type
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]  #dataframe
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df['continent'] #series type
visa_df[['continent']]  #dataframe
visa_df.continent  #series
visa_df.loc[:,['continent']] #dataframe
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %% [markdown]
# **read multiple columns**
#
# - whenever we see multiple means recall the list
#
# - keep the name of the columns in a list
#
# - pass the list

# %%
cols=['continent','case_status']
visa_df[cols]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %% [markdown]
# $task-1$
#
# **we want to find the number of applicants continent wise**
#
# - there is an asia continet is there
#
# - how many are from asia out of 25480

# %% [markdown]
# **unique**
#
# - unique will provide how many unique items are there in a particular column

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(visa_df['continent'].unique())
# Out:
# 6

# %% [markdown]
# **nunique**
#
# - gives count of unique items

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %%
#step-1:read the data with specific column
#step-2:apply the condition
        #when we apply the condition python will give true and false 
#step-3:in order to retrive the true data
        #dataframe_nmae[condition]

# %%
con=visa_df['continent']=='Asia' #it's a condition 
#dataframe_name[condition]
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df[con])
# Out:
# 16861

# %%
li=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count=len(visa_df[con])
    print(f'the number of applicant from {i} is : {count}')
# Out:
# the number of applicant from Asia is : 16861
# the number of applicant from Africa is : 551
# the number of applicant from North America is : 3292
# the number of applicant from Europe is : 3732
# the number of applicant from South America is : 852
# the number of applicant from Oceania is : 192

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %% [markdown]
# $task-2$
#
# - now instead of print count take a empty list
#
# - save the values
#
# - we already has unique continent list
#
# - we also have count list
#
# - create a  dataframe

# %%
count=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))
count
# Out:
# [16861, 551, 3292, 3732, 852, 192]

# %%
continent=visa_df['continent'].unique()

# %%
cols=['continent','no. of applicants']
continent_df=pd.DataFrame(zip(continent,count),columns=cols)
continent_df
# Out:
#        continent  no. of applicants
# 0           Asia              16861
# 1         Africa                551
# 2  North America               3292
# 3         Europe               3732
# 4  South America                852
# 5        Oceania                192

# %%
continent_df.to_csv('continent_df.csv',index=False)

# %% [markdown]
# **30.7.24**

# %%
cdf=visa_df['continent'].value_counts()
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %% [markdown]
# - we created a dataframe of unique values of a column and its count
#
# - we created it by our ouwn way, using loops
#
# - the same operation we can  get using value_counts

# %%
dir(cdf)
# Out:
# ['Africa',
#  'Asia',
#  'Europe',
#  'Oceania',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
type(cdf)
# Out:
# pandas.core.series.Series

# %%
keys=cdf.keys()

# %%
values=cdf.values

# %%
cols=['labels','count']
df1=pd.DataFrame(zip(keys,values),columns=cols)
df1.to_csv('continents.csv',index=False)

# %% [markdown]
# **make all dataframe of  all the cols which is objecct type**
#
# **create diffrent csv file**

# %%
cat1
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
for i in cat1:
    cdf=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['labels','count']
    df1=pd.DataFrame(zip(keys,values),columns=cols)
    path=r"C:\Users\akash\OneDrive\Desktop\data science\EDA\value_count_df" #to store the file in that location 
    df1.to_csv(f'{path}\\{i}.csv',index=False)

# %% [markdown]
# **normalize**
#
# - relative frequency table
#
# - will give percentage of labels in column

# %%
cdf=visa_df['continent'].value_counts(normalize=True)
round(cdf*100,2)
# Out:
# continent
# Asia             66.17
# Europe           14.65
# North America    12.92
# South America     3.34
# Africa            2.16
# Oceania           0.75
# Name: proportion, dtype: float64

# %% [markdown]
# **Bar Chart**
#
# - it is the graphical representation of frequency table
#
# - it is a plot between count and class
#
# -  in order  to plot it we required 2 columns
#
#     - categorical column
#
#     - numerical column
#
# - we already created a frequency table for **continents_df**
#
#     - here we have cols=['continent','no. of applicants']
#
#     - categorical column is **continents**
#
#     - numerical column is **number of applicants**
#
# - package: **matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
continent_df
# Out:
#        continent  no. of applicants
# 0           Asia              16861
# 1         Africa                551
# 2  North America               3292
# 3         Europe               3732
# 4  South America                852
# 5        Oceania                192

# %%
plt.bar('continent' #cat column x-axis
        ,'no. of applicants' #num column height: y-axis
        ,data=continent_df)
plt.title('Bar Chart') #tittle of the graph
plt.xlabel('Continent')#x-axis name
plt.ylabel('no. of applicants')#y-axis name
plt.savefig('Continent_bar_chat.jpg')
plt.show()#it will avoid the write up and it should be at last

# %%
for i in cat1[1:]:
    cdf=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['labels','count']
    df1=pd.DataFrame(zip(keys,values),columns=cols)
    plt.bar('labels' #cat column x-axis
            ,'count' #num column height: y-axis
            ,data=df1)
    plt.title(f'{i} Bar Chart') #tittle of the graph
    plt.xlabel('labels')#x-axis name
    plt.ylabel('count')#y-axis name
    path=r"C:\Users\akash\OneDrive\Desktop\data science\EDA\value_count_df"
    plt.savefig(f'{path}\\{i}.jpg')
    plt.show()

# %% [markdown]
# **31.7.24**

# %% [markdown]
# **bar chart using seaborn**
#
# - we can plot bar charts using with many packages
#
# - one package is matplotlib
#
# - another package is seaborn
#
# - in matplotlib the method is **plt.bar**
#
# - in seaborn the method **countplot**
#
# - in matplotlib
#
#     - we will take the  raw data
#
#     - we will create our frequency table i.e dataframe
#
#     - we will pass the column1,column2 and dataframe name
#
# - in seaborn count plot
#
#     - it takes direct raw data
#
#     - we will provide directcolumn name
#
#     - we will provide main dataframe name

# %%
import seaborn as sns
plt.figure(figsize=(9,5))
order_line=['Asia','Europe','North America','South America','Africa','Oceania']
sns.countplot(data=visa_df,
              x='continent',
             order=order_line,
             )
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %% [markdown]
# **1.8.24**

# %% [markdown]
# **usinf for loop plot chart of all that cat columns**
#
# - we can use seaborn and matplotlib
#
# - seaborn: countplot requires only raw data ,direct data column name and main data
#
# - matplotlib: requires frequency table
#
#     - from raw data , will make value counts
#
#     - from value counts we are making keys and value separetly
#
#     - then we are creating dataframe
#
# - start with seaborn
#
#     - then we require  cat column
#
#     - and main dataframe
#
# - start with matplotlib
#
#     - we already created a folder in our laptop:value_count_df

# %%
import seaborn as sns
for i in cat1[1:]:
    plt.figure(figsize=(9,5))
    order_line=visa_df[i].value_counts().keys()
    sns.countplot(data=visa_df,x=i,order=order_line,)
    plt.title(f'{i} Bar Chart') #tittle of the graph
    #plt.xlabel('labels')#x-axis name
    #plt.ylabel('count')#y-axis name

# %% [markdown]
# **how to create a folder**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\akash\\OneDrive\\Desktop\\data science\\EDA'

# %% [markdown]
# **os.mkdir**
#
# - it creata a leaf directory
#
# - means it will take the current working directory and create one extra folder
#
# - here my python file in **EDA** folder
#
# - now i want to create a new folder **graph_seaborn**
#
# - which is one step ahead of EDAf :EDA/graph_seaborn
#
# - pass the full path inside the mkdir()
#
# - path='C:\\Users\\akash\\OneDrive\\Desktop\\data science\\EDA\graph_seaborn'

# %%
#step-1
root_directory=os.getcwd()
root_directory

#step-2
new_folder='graph'

#step-3
new_dir=os.path.join(root_directory,new_folder)
new_dir

#step-4
os.makedirs(new_dir)

# %%
os.mkdir(r'C:\Users\akash\OneDrive\Desktop\data science\EDA\graph_seaborn')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 os.mkdir(r'C:\Users\akash\OneDrive\Desktop\data science\EDA\graph_seaborn')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\akash\\OneDrive\\Desktop\\data science\\EDA\\graph_seaborn'

# %%
os.getcwd()

# %%
os.chdir(r'C:\Users\akash\OneDrive\Desktop\data science\EDA\graph_seaborn')

# %%
os.getcwd()

# %%
dir(os)

# %%
os.chdir('..') #to change the directory

# %%
os.getcwd()

# %%
os.rmdir('graph') # to delete the directory

# %% [markdown]
# **using matplotlib**

# %%
for i in cat1[1:]:
    cdf=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['labels','count']
    df1=pd.DataFrame(zip(keys,values),columns=cols)
    plt.bar('labels' #cat column x-axis
            ,'count' #num column height: y-axis
            ,data=df1)
    plt.title(f'{i} Bar Chart') #tittle of the graph
    plt.xlabel('labels')#x-axis name
    plt.ylabel('count')#y-axis name
    #path=r"C:\Users\akash\OneDrive\Desktop\data science\EDA\value_count_df"
    #plt.savefig(f'{path}\\{i}.jpg')
    plt.show()

# %% [markdown]
# **2.8.24**

# %% [markdown]
# **subplots**

# %% [markdown]
# - if we have multiple plots when we apply for loop  it is giving one by one
#
# - it is hard to see all the graph
#
# - subplot is a kind of a matrix represenatation
#
# - suppose we have a 2x2 matrix means 4 values , means 4 plots we can plot
#
# - first plot position represents with : (2,2,1)
#
# - second plot position represents with : (2,2,2)
#
# - third plot position represents with : (2,2,3)
#
# - fourth plot position represents with : (2,2,4)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.subplot(2,1,1)
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
#read the data again take 2 columns 
#1 is continent
#2 case satus
#draaw the seaborn indivisualy

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='continent',data=visa_df)
plt.subplot(1,2,2)
sns.countplot(x='case_status',data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
plt.figure(figsize=(14,11))
plt.subplot(2,2,1)
sns.countplot(x='continent',data=visa_df)
plt.title('continent_bar_chart')

plt.subplot(2,2,2)
sns.countplot(x='case_status',data=visa_df)
plt.title('case_status_bar_chart')

plt.subplot(2,2,3)
sns.countplot(x='has_job_experience',data=visa_df)
plt.title('has_job_experience_bar_chart')

plt.subplot(2,2,4)
sns.countplot(x='requires_job_training',data=visa_df)
plt.title('requires_job_training_bar_chart')

plt.savefig('subplot.jpg')
plt.show()

# %%
cat1
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
plt.figure(figsize=(20,11))
for i in range(len(cat1[1:])):
    plt.subplot(3,3,i+1)
    sns.countplot(x=cat1[i+1],data=visa_df)

# %% [markdown]
# **5.4.24**

# %% [markdown]
#  **method-3**

# %%
**whenever open the file

# %%
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
type=dict(visa_df.dtypes)
numerical_data=[i for i,j in data.items() if j!='object' ]
catgorical_data=[i for i,j in data.items() if j=='object' ]
catgorical_data
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
cd=visa_df['continent'].value_counts()
cd
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
new_method=cd.plot(kind='bar')
new_method.bar_label(new_method.containers[0])
plt.show()
