# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

path=r"C:\Users\akash\OneDrive\Desktop\data science\data files\Visadataset.csv"


visa_df=pd.read_csv(path)
cat_column=visa_df.select_dtypes(include='object').columns
num_column=visa_df.select_dtypes(exclude='object').columns
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **encoding**
#
# - it means convert cat column to num columnds
#
# - because Ml model except the data should be in numerical format
#
# - ml method developed by math algo
#
# - it is vary imp to apply encoding
#
# - the following methods used are
#
#     - map
#
#     - np.where
#
#     - one hot encoding
#
#     - label encoder

# %% [markdown]
# **map method**
#
# - map is one method to convert categorical values to numerical column
#
# - take one cat column
#
# - get the unique labes 1st
#
# - make a dictionary with  assign a number to each label
#
# - for example case_status has 2 lables
#
#     - certified
#
#     - denied
#
# - assign 0 to certified and  1 to denied
#
# - create a dict labels as key and number as value only

# %%
#step-1: read columns
#step-2: get unique labels
#step-3:make a dictionary
#step-4: apply the map

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# d={'Certified':0,'Denied':1}
# visa_df['case_status_new']=visa_df['case_status'].map(d)
# visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **16.8.24**

# %%
#i want to apply map for all cat columns
#step-1:we need to get unique labels
#step-2: we need to get a numbers = len unique labels
#step-3:we need to create a dictionary

# %%
unique_labels=sorted(visa_df['case_status'].unique())
#unique_labels.sort()
list1=[i for i in range (len(unique_labels))]
unique_labels,list1
# Out:
# (['Certified', 'Denied'], [0, 1])

# %%
#visa_df=pd.read_csv(path)
dic1=dict(zip(unique_label,list1))
visa_df['case_status']=visa_df['case_status'].map(dic1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dic={key:value for key,value in zip(unique_labels,list1)}
dic
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
for i in cat_column:
    un_labels=sorted(visa_df[i].unique())
    li=[i for i in range (len(un_labels))]
    Dic=dict(zip(un_labels,li))
    visa_df[i]=visa_df[i].map(Dic)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# *labelencoder*
#
# - it is a method to convert cat data to num
#
# - it is same as how we did in the above
#
# - the for loop map method we explored
#
# - but the label encoder also do the same
#
# - it is under 'skykit-learn' and usually called as *skylearn*
#
# - under skylearn we have a class called preprocessing
#
# - coz currently we are doing data preprocessing
#
# - under preprocessing class we have a metod called *labelencoder*
#
# -sklearn ---- preprocessing ----- lableencoder
#
# - any sklearn have 3 step
#
#     - 1 read the package
#
#     - 2 save the package
#
#     - 3 apply fit transform on data

# %%
#read the data
visa_df=pd.read_csv(path)
#step-1: read the pakage/load the method
from sklearn.preprocessing import LabelEncoder
#step-2: save the package/call the method
le=LabelEncoder()
#step-3: applyt  fit transformation on a data
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(path)
for i in cat_column:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform**
#
# - fit means devlope the logic
#
# - transform means process the logic
#
# - if we observe in map  method 1st we developed dictionary logic
#
# - then we apply that dictionary to column
#
# - devloping the dictionary is kind of fit
#
# - applying the dictionary to column means we are transforming the data cat to num
#
# - whenever we are transforming or changing the data then use  **fit transform**
#
# - if we are not changing the data then only fit

# %% [markdown]
# **np.where**

# %% [markdown]
# - using np.where also we can change the categorical data to numerical
#
# - but np.where is only for binary condition
#
# -  np.where is same as if-else
#
# - if condition is True: will apply True value
#
# - if condition is False: will apply False value
#
# - so np.where use for only binary labels
#
# - a column should have only 2 unique labels

# %%
visa_df=pd.read_csv(path)
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **one hot encoder**
#
# - one hot means if one will be ON, another will be OFF
#
# - ON represents with 1
#
# - OFF represents with 0
#
# - for example  case status hase two unique labels
#
#     - certified
#
#     - denied
#
# - one hot encoder creates new column which is equal to number of unique labels
#
# - for example case status will creat 2 new extra column
#
#     - case_status_Certified
#
#     - case_status_Denied
#
# |case_status|case_status_Certified|case_status_denied|
# |-|-|-|
# |Denied|0|1|
# |Ceritifed|1|0|
# |Denied|0|1|
